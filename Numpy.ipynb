# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 디렉토리 변경
cd '/content/drive/MyDrive/Numpy_and_Pandas/Numpy'
# Out:
# /content/drive/MyDrive/Numpy_and_Pandas/Numpy

# %%
# 넘파이 임포트
import numpy as np

# %%
# 폴더 add
# !git add Numpy.ipynb

# %%
# 커밋하기
# !git commit -m 'Lets go'
# !git push
# Out:
# [main 8b201c5] Lets go
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 932 bytes | 84.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/NUMCHCOMCH/Numpy.git
#    5973b7a..8b201c5  main -> main
