# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 디렉토리 변경
cd '/content/drive/MyDrive/Numpy_and_Pandas/Numpy'
# Out:
# /content/drive/MyDrive/Numpy_and_Pandas/Numpy

# %%
# 본인임을 증명
# !git config --global user.email 'anstmdwn34@gmail.com'
# !git config --global user.name 'NUMCHCOMCH'

# %%
# 넘파이 임포트
import numpy as np

# %%
# 폴더 add
# !git add Numpy.ipynb

# %%
# 커밋하기
# !git commit -m 'Lets go'
# !git push
# Out:
# [main (root-commit) 5973b7a] Lets go
#  1 file changed, 1 insertion(+)
#  create mode 100644 Numpy.ipynb
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 986 bytes | 98.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/NUMCHCOMCH/Numpy.git
#  * [new branch]      main -> main
